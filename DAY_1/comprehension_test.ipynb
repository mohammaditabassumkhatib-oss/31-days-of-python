# %% [markdown]
# 1. [x * 2 for x in [1, 2, 3]]

# %%
square = [x * 2 for x in [1, 2, 3]]
print(square)
# Out:
# [2, 4, 6]

# %% [markdown]
# 2. [x for x in range(10) if x % 2 == 0]

# %%
even_num = [x for x in range(10) if x%2 == 0]
